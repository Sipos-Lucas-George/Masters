# %% [markdown]
# # Lab 4 Tasks

# %% [markdown]
# ## Task 1 - JSON Parsing

# %% [markdown]
# Use Python to download a file containing movie metadata in JSON format from the URL:
#
# http://mlg.ucd.ie/modules/COMP41680/movies.json

# %%
import urllib.request
url = "http://mlg.ucd.ie/modules/COMP41680/movies.json"
response = urllib.request.urlopen(url)
text = response.read().decode()
print(text)
# Out:
# [{
# 	"Title": "London Has Fallen",
# 	"Year": "2016",
# 	"Rated": "R",
# 	"Runtime": "99 min",
# 	"Genre": "Action, Crime, Thriller",
# 	"Director": "Babak Najafi",
# 	"Actors": "Gerard Butler, Morgan Freeman, Charlotte Riley, Angela Bassett",
# 	"Country": "UK, USA, Bulgaria",
# 	"RatingScore": "28",
# 	"Type": "movie"
# }, {
# 	"Title": "Deadpool",
# 	"Year": "2016",
# 	"Rated": "R",
# 	"Runtime": "108 min",
# 	"Genre": "Action, Adventure, Comedy",
# 	"Director": "Tim Miller",
# 	"Actors": "Ryan Reynolds, Karan Soni, Ed Skrein, Michael Benyaer",
# 	"Country": "USA, Canada",
# 	"RatingScore": "65",
# 	"Type": "movie"
# }, {
# 	"Title": "Kung Fu Panda 3",
# 	"Year": "2016",
# 	"Rated": "PG",
# 	"Runtime": "95 min",
# 	"Genre": "Animation, Action, Adventure",
# 	"Director": "Alessandro Carloni, Jennifer Yuh",
# 	"Actors": "Jack Black, Bryan Cranston, Dustin Hoffman, Angelina Jolie",
# 	"Country": "China, USA",
# 	"RatingScore": "64",
# 	"Type": "movie"
# }, {
# 	"Title": "Spectre",
# 	"Year": "2015",
# 	"Rated": "PG-13",
# 	"Runtime": "148 min",
# 	"Genre": "Action, Adventure, Thriller",
# 	"Director": "Sam Mendes",
# 	"Actors": "Daniel Craig, Christoph Waltz, Léa Seydoux, Ralph Fiennes",
# 	"Country": "UK, USA",
# 	"RatingScore": "60",
# 	"Type": "movie"
# }, {
# 	"Title": "Brooklyn",
# 	"Year": "2015",
# 	"Rated": "PG-13",
# 	"Runtime": "111 min",
# 	"Genre": "Drama, Romance",
# 	"Director": "John Crowley",
# 	"Actors": "Saoirse Ronan, Hugh Gormley, Brid Brennan, Jim Broadbent",
# 	"Country": "Ireland, UK, Canada",
# 	"RatingScore": "87",
# 	"Type": "movie"
# }, {
# 	"Title": "The Revenant",
# 	"Year": "2015",
# 	"Rated": "R",
# 	"Runtime": "156 min",
# 	"Genre": "Adventure, Drama, Thriller",
# 	"Director": "Alejandro González Iñárritu",
# 	"Actors": "Leonardo DiCaprio, Tom Hardy, Domhnall Gleeson, Will Poulter",
# 	"Country": "USA",
# 	"RatingScore": "76",
# 	"Type": "movie"
# }, {
# 	"Title": "1917",
# 	"Year": "2019",
# 	"Rated": "R",
# 	"Runtime": "119 min",
# 	"Genre": "Drama, War",
# 	"Director": "Sam Mendes",
# 	"Actors": "Dean-Charles Chapman, George MacKay, Daniel Mays, Colin Firth",
# 	"Country": "USA",
# 	"RatingScore": "78",
# 	"Type": "movie"
# }, {
# 	"Title": "Joker",
# 	"Year": "2019",
# 	"Rated": "R",
# 	"Runtime": "122 min",
# 	"Genre": "Crime, Drama, Thriller",
# 	"Director": "Todd Phillips",
# 	"Actors": "Joaquin Phoenix, Robert De Niro, Zazie Beetz, Frances Conroy",
# 	"Country": "USA",
# 	"RatingScore": "59",
# 	"Type": "movie"
# }, {
# 	"Title": "Uncut Gems",
# 	"Year": "2019",
# 	"Rated": "R",
# 	"Runtime": "135 min",
# 	"Genre": "Crime, Drama, Thriller",
# 	"Director": "Benny Safdie, Josh Safdie",
# 	"Actors": "Mesfin Lamengo, Sun Zhi Hua-Hilton, Liang Wei-Hui-Duncan, Sunny Wu Jin Zahao",
# 	"Country": "USA",
# 	"RatingScore": "90",
# 	"Type": "movie"
# }, {
# 	"Title": "Knives Out",
# 	"Year": "2019",
# 	"Rated": "PG-13",
# 	"Runtime": "131 min",
# 	"Genre": "Comedy, Crime, Drama, Mystery, Thriller",
# 	"Director": "Rian Johnson",
# 	"Actors": "Daniel Craig, Chris Evans, Ana de Armas, Jamie Lee Curtis",
# 	"Country": "USA",
# 	"RatingScore": "82",
# 	"Type": "movie"
# }, {
# 	"Title": "Jumanji: The Next Level",
# 	"Year": "2019",
# 	"Director": "Jake Kasdan",
# 	"Rated": "PG-13",
# 	"Runtime": "123 min",
# 	"Genre": "Action, Adventure, Comedy, Fantasy",
# 	"Actors": "Dwayne Johnson, Kevin Hart, Jack Black, Karen Gillan",
# 	"Country": "USA",
# 	"RatingScore": "58",
# 	"Type": "movie"
# }, {
# 	"Title": "Venom",
# 	"Year": "2018",
# 	"Rated": "PG-13",
# 	"Runtime": "112 min",
# 	"Genre": "Action, Sci-Fi, Thriller",
# 	"Director": "Ruben Fleischer",
# 	"Actors": "Tom Hardy, Michelle Williams, Riz Ahmed, Scott Haze",
# 	"Country": "China, USA",
# 	"RatingScore": "35",
# 	"Type": "movie"
# }, {
# 	"Title": "Incredibles 2",
# 	"Year": "2018",
# 	"Rated": "PG",
# 	"Runtime": "118 min",
# 	"Genre": "Animation, Action, Adventure, Comedy, Family, Sci-Fi",
# 	"Director": "Brad Bird",
# 	"Country": "USA",
# 	"Actors": "Craig T. Nelson, Holly Hunter, Sarah Vowell, Huck Milner",
# 	"RatingScore": "80",
# 	"Type": "movie"
# }, {
# 	"Title": "Suspiria",
# 	"Year": "2018",
# 	"Rated": "R",
# 	"Runtime": "152 min",
# 	"Genre": "Fantasy, Horror, Mystery, Thriller",
# 	"Director": "Luca Guadagnino",
# 	"Actors": "Chloë Grace Moretz, Tilda Swinton, Doris Hick, Malgorzata Bela",
# 	"Country": "Italy, USA",
# 	"RatingScore": "64",
# 	"Type": "movie"
# }, {
# 	"Title": "A Quiet Place",
# 	"Year": "2018",
# 	"Rated": "PG-13",
# 	"Runtime": "90 min",
# 	"Genre": "Drama, Horror, Sci-Fi",
# 	"Director": "John Krasinski",
# 	"Actors": "Emily Blunt, John Krasinski, Millicent Simmonds, Noah Jupe",
# 	"Country": "USA",
# 	"RatingScore": "82",
# 	"Type": "movie"
# }]

# %% [markdown]
# Parse the JSON data that you have downloaded.

# %%
import json
data = json.loads(text)
print(data)
# Out:
# [{'Title': 'London Has Fallen', 'Year': '2016', 'Rated': 'R', 'Runtime': '99 min', 'Genre': 'Action, Crime, Thriller', 'Director': 'Babak Najafi', 'Actors': 'Gerard Butler, Morgan Freeman, Charlotte Riley, Angela Bassett', 'Country': 'UK, USA, Bulgaria', 'RatingScore': '28', 'Type': 'movie'}, {'Title': 'Deadpool', 'Year': '2016', 'Rated': 'R', 'Runtime': '108 min', 'Genre': 'Action, Adventure, Comedy', 'Director': 'Tim Miller', 'Actors': 'Ryan Reynolds, Karan Soni, Ed Skrein, Michael Benyaer', 'Country': 'USA, Canada', 'RatingScore': '65', 'Type': 'movie'}, {'Title': 'Kung Fu Panda 3', 'Year': '2016', 'Rated': 'PG', 'Runtime': '95 min', 'Genre': 'Animation, Action, Adventure', 'Director': 'Alessandro Carloni, Jennifer Yuh', 'Actors': 'Jack Black, Bryan Cranston, Dustin Hoffman, Angelina Jolie', 'Country': 'China, USA', 'RatingScore': '64', 'Type': 'movie'}, {'Title': 'Spectre', 'Year': '2015', 'Rated': 'PG-13', 'Runtime': '148 min', 'Genre': 'Action, Adventure, Thriller', 'Director': 'Sam Mendes', 'Actors': 'Daniel Craig, Christoph Waltz, Léa Seydoux, Ralph Fiennes', 'Country': 'UK, USA', 'RatingScore': '60', 'Type': 'movie'}, {'Title': 'Brooklyn', 'Year': '2015', 'Rated': 'PG-13', 'Runtime': '111 min', 'Genre': 'Drama, Romance', 'Director': 'John Crowley', 'Actors': 'Saoirse Ronan, Hugh Gormley, Brid Brennan, Jim Broadbent', 'Country': 'Ireland, UK, Canada', 'RatingScore': '87', 'Type': 'movie'}, {'Title': 'The Revenant', 'Year': '2015', 'Rated': 'R', 'Runtime': '156 min', 'Genre': 'Adventure, Drama, Thriller', 'Director': 'Alejandro González Iñárritu', 'Actors': 'Leonardo DiCaprio, Tom Hardy, Domhnall Gleeson, Will Poulter', 'Country': 'USA', 'RatingScore': '76', 'Type': 'movie'}, {'Title': '1917', 'Year': '2019', 'Rated': 'R', 'Runtime': '119 min', 'Genre': 'Drama, War', 'Director': 'Sam Mendes', 'Actors': 'Dean-Charles Chapman, George MacKay, Daniel Mays, Colin Firth', 'Country': 'USA', 'RatingScore': '78', 'Type': 'movie'}, {'Title': 'Joker', 'Year': '2019', 'Rated': 'R', 'Runtime': '122 min', 'Genre': 'Crime, Drama, Thriller', 'Director': 'Todd Phillips', 'Actors': 'Joaquin Phoenix, Robert De Niro, Zazie Beetz, Frances Conroy', 'Country': 'USA', 'RatingScore': '59', 'Type': 'movie'}, {'Title': 'Uncut Gems', 'Year': '2019', 'Rated': 'R', 'Runtime': '135 min', 'Genre': 'Crime, Drama, Thriller', 'Director': 'Benny Safdie, Josh Safdie', 'Actors': 'Mesfin Lamengo, Sun Zhi Hua-Hilton, Liang Wei-Hui-Duncan, Sunny Wu Jin Zahao', 'Country': 'USA', 'RatingScore': '90', 'Type': 'movie'}, {'Title': 'Knives Out', 'Year': '2019', 'Rated': 'PG-13', 'Runtime': '131 min', 'Genre': 'Comedy, Crime, Drama, Mystery, Thriller', 'Director': 'Rian Johnson', 'Actors': 'Daniel Craig, Chris Evans, Ana de Armas, Jamie Lee Curtis', 'Country': 'USA', 'RatingScore': '82', 'Type': 'movie'}, {'Title': 'Jumanji: The Next Level', 'Year': '2019', 'Director': 'Jake Kasdan', 'Rated': 'PG-13', 'Runtime': '123 min', 'Genre': 'Action, Adventure, Comedy, Fantasy', 'Actors': 'Dwayne Johnson, Kevin Hart, Jack Black, Karen Gillan', 'Country': 'USA', 'RatingScore': '58', 'Type': 'movie'}, {'Title': 'Venom', 'Year': '2018', 'Rated': 'PG-13', 'Runtime': '112 min', 'Genre': 'Action, Sci-Fi, Thriller', 'Director': 'Ruben Fleischer', 'Actors': 'Tom Hardy, Michelle Williams, Riz Ahmed, Scott Haze', 'Country': 'China, USA', 'RatingScore': '35', 'Type': 'movie'}, {'Title': 'Incredibles 2', 'Year': '2018', 'Rated': 'PG', 'Runtime': '118 min', 'Genre': 'Animation, Action, Adventure, Comedy, Family, Sci-Fi', 'Director': 'Brad Bird', 'Country': 'USA', 'Actors': 'Craig T. Nelson, Holly Hunter, Sarah Vowell, Huck Milner', 'RatingScore': '80', 'Type': 'movie'}, {'Title': 'Suspiria', 'Year': '2018', 'Rated': 'R', 'Runtime': '152 min', 'Genre': 'Fantasy, Horror, Mystery, Thriller', 'Director': 'Luca Guadagnino', 'Actors': 'Chloë Grace Moretz, Tilda Swinton, Doris Hick, Malgorzata Bela', 'Country': 'Italy, USA', 'RatingScore': '64', 'Type': 'movie'}, {'Title': 'A Quiet Place', 'Year' ...

# %% [markdown]
# From the parsed JSON data, print a list of the all of the movie titles, along with the duration of each movie.

# %%
for movie in data:
    print(f"{movie['Title']} : {movie['Runtime']}")
# Out:
# London Has Fallen : 99 min
# Deadpool : 108 min
# Kung Fu Panda 3 : 95 min
# Spectre : 148 min
# Brooklyn : 111 min
# The Revenant : 156 min
# 1917 : 119 min
# Joker : 122 min
# Uncut Gems : 135 min
# Knives Out : 131 min
# Jumanji: The Next Level : 123 min
# Venom : 112 min
# Incredibles 2 : 118 min
# Suspiria : 152 min
# A Quiet Place : 90 min

# %% [markdown]
# Extract and print the genre information for each movie.

# %%
movie_genre = [[movie['Title'], movie['Genre']] for movie in data]
for movie in movie_genre:
    print("{} : {}".format(*movie))
# Out:
# London Has Fallen : Action, Crime, Thriller
# Deadpool : Action, Adventure, Comedy
# Kung Fu Panda 3 : Animation, Action, Adventure
# Spectre : Action, Adventure, Thriller
# Brooklyn : Drama, Romance
# The Revenant : Adventure, Drama, Thriller
# 1917 : Drama, War
# Joker : Crime, Drama, Thriller
# Uncut Gems : Crime, Drama, Thriller
# Knives Out : Comedy, Crime, Drama, Mystery, Thriller
# Jumanji: The Next Level : Action, Adventure, Comedy, Fantasy
# Venom : Action, Sci-Fi, Thriller
# Incredibles 2 : Animation, Action, Adventure, Comedy, Family, Sci-Fi
# Suspiria : Fantasy, Horror, Mystery, Thriller
# A Quiet Place : Drama, Horror, Sci-Fi

# %% [markdown]
# Export the complete movie data to a new file in CSV format.

# %%
import pandas as pd

df = pd.DataFrame(data)
df.to_csv("movies_new.csv", index=False, header=True)
# print(data)

# %% [markdown]
# ## Task 2 - XML Parsing

# %% [markdown]
# Use Python to download a file containing a contact list in XML format from the URL:
#
# http://mlg.ucd.ie/modules/COMP41680/contacts.xml

# %%
url = "http://mlg.ucd.ie/modules/COMP41680/contacts.xml"
response = urllib.request.urlopen(url)
text = response.read().decode()
print(text)
# Out:
# <?xml version="1.0"?>
# <contacts>
#   <contact>
#     <name>John Smith</name>
#     <phone>085-456-7890</phone>
#     <email>johnsmith243@gmail.com</email>
#   </contact>
#   <contact>
#     <name>Alice Murphy</name>
#     <phone>086-456-7891</phone>
#     <email>alice.murphy12@ucd.ie</email>
#   </contact>
#   <contact>
#     <name>Joe Adams</name>
#     <phone>086-222-4654</phone>
#     <email>joeadams2016@tcd.ie</email>
#   </contact>
#   <contact>
#     <name>Carol Conroy</name>
#     <phone>087-131-1331</phone>
#     <email>cconry1342@gmail.com</email>
#   </contact>
#   <contact>
#     <name>Mary Carthy</name>
#     <phone>086-221-7433</phone>
#     <email>mcarthy1987@ucd.ie</email>
#   </contact>
# </contacts>

# %% [markdown]
# Parse the XML data that you have downloaded.

# %%
import xml.etree.ElementTree
data = xml.etree.ElementTree.fromstring(text)
print(data)
# Out:
# <Element 'contacts' at 0x1363fedb0>

# %% [markdown]
# From the parsed XML data, extract the name, email address and phone number of each contact.
#
# Store these contacts in a list of dictionaries, and print them out.

# %%
contacts = list()
for child in data.findall("contact"):
    contacts.append({
        'name': child[0].text,
        'phone': child[1].text,
        'email': child[2].text,
    })
print(contacts)
# Out:
# [{'name': 'John Smith', 'phone': '085-456-7890', 'email': 'johnsmith243@gmail.com'}, {'name': 'Alice Murphy', 'phone': '086-456-7891', 'email': 'alice.murphy12@ucd.ie'}, {'name': 'Joe Adams', 'phone': '086-222-4654', 'email': 'joeadams2016@tcd.ie'}, {'name': 'Carol Conroy', 'phone': '087-131-1331', 'email': 'cconry1342@gmail.com'}, {'name': 'Mary Carthy', 'phone': '086-221-7433', 'email': 'mcarthy1987@ucd.ie'}]

# %% [markdown]
# Export the contact data to a new file in CSV format.

# %%
df = pd.DataFrame(contacts)
df.to_csv("contacts_new.csv", index=False, header=True)

# %% [markdown]
# Use Pickle to serialise the contact data to a file. Verify that you can deseralise the data again.

# %%
import pickle

with open("contacts_new.pkl", "wb") as file:
    pickle.dump(contacts, file)
    
with open("contacts_new.pkl", "rb") as file:
    print(pickle.load(file))
# Out:
# [{'name': 'John Smith', 'phone': '085-456-7890', 'email': 'johnsmith243@gmail.com'}, {'name': 'Alice Murphy', 'phone': '086-456-7891', 'email': 'alice.murphy12@ucd.ie'}, {'name': 'Joe Adams', 'phone': '086-222-4654', 'email': 'joeadams2016@tcd.ie'}, {'name': 'Carol Conroy', 'phone': '087-131-1331', 'email': 'cconry1342@gmail.com'}, {'name': 'Mary Carthy', 'phone': '086-221-7433', 'email': 'mcarthy1987@ucd.ie'}]
